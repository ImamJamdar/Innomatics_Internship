# %% [markdown]
# Chatbot using Transformers (**DialoGPT**)
#
# **Objective**
#
# This project builds a conversational chatbot using a pre-trained transformer model from Hugging Face.
#
#
# **Technologies Used**
# - Python
# - Hugging Face Transformers
# - PyTorch
# - Google Colab
#
#
# **Description**
#
# The chatbot interacts with users using natural language and generates responses dynamically using DialoGPT.

# %%
# Installing Hugging Face transformers library
# !pip install transformers sentencepiece

# %%
# Importing necessary libraries
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

# %%
# Loading FLAN-T5 model (very good for Q&A and conversation)

tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-large")
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-large")

print("Model loaded successfully!")
# Out:
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/558 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Model loaded successfully!

# %%
print("Chatbot: Hello! I am your AI assistant. How can I help you today?")

# Conversation loop
while True:

    user_input = input("You: ")

    # Exit condition
    if user_input.lower() in ["exit", "quit"]:
        print("Chatbot: Goodbye! Have a great day 😊")
        break

    # Creating a better prompt (THIS IS THE MAGIC 🔥)
    prompt = f"""
    You are a helpful and intelligent AI assistant.
    Answer the user's question clearly and accurately.

    User: {user_input}
    Chatbot:
    """

    # Tokenizing input
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True)

    # Generating response
    outputs = model.generate(
        inputs.input_ids,
        max_length=200,
        temperature=0.7,
        top_p=0.9,
        do_sample=True
    )

    # Decoding response
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)

    print("Chatbot:", response)
# Out:
# Chatbot: Hello! I am your AI assistant. How can I help you today?
# You: hi
# Chatbot: no chat agent.please contact one,the human'y chat and answer i will loveyou by reply reply be at me for you
# You: what is AI?
# Chatbot: not bad you should probably choose good mamishio names? its
# You: exit
# Chatbot: Goodbye! Have a great day 😊
